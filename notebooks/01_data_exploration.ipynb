# %% [markdown]
# # RetailPulse Analytics — Data Exploration
#
# This notebook performs an exploratory data analysis (EDA) on the retail sales dataset.

# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/clean_sales.csv")

# %% [markdown]
# # Visão geral

# %%
df.head()
df.info()
df.describe()

# %% [markdown]
# # Valores nulos

# %%
df.isnull().sum()

# %% [markdown]
# # Distribuição de vendas

# %%
df["sales"].hist(bins=30)

plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")

plt.show()
